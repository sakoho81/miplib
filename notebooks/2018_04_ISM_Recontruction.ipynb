# %% [markdown]
# # ISM Reconstruction
#
# In ISM several slightly shifted images are recroded with a detector array and at the reconstruction stage they need to be fused together to generate a higher-SNR (and resolution) output image.

# %%
# %matplotlib inline

import os
from scipy.io import loadmat
import numpy as np
from supertomo.data.io import carma
from supertomo.ui.plots import image as implots

# Image
data_dir = os.path.join(os.getcwd(), "data")
filename = "20170301_110453_725.mat"
full_path = os.path.join(data_dir, filename)

# %% [markdown]
# ## Import Data
#
# The image data is contained in a special Carma file format. Images are organized according to 1. the detector they were recorded with and 2. the laser gate number during which they were recorded. There's a special data structure *ArrayDetectorData* for holding such image collections in memory inside SuperTomo. Alternatively a HDF5 based *ImageData* structure can be used, in case the images are very large.

# %%
data = carma.read_carma_mat(full_path)
implots.display_2d_images(data[0,12], data[0,8])

# %% [markdown]
# ## Evaluate data quality
#
# The template image shown holds information of the effective system PSF and also it can be used to evaluate how well the detector was aligned during data acquisition.

# %%
from supertomo.processing.ism import helpers as ismhelpers

template = ismhelpers.make_template_image(data)

implots.display_2d_image(template[0])

# %% [markdown]
# ## Registration
#
# In order to perform the reassignment the images have to be registered (aligned into a single coordinate grid). For this I use a iterative image registration algorithm that I originally developed for a CLEM application. Let's first try this out with a single image pair. The image number 12 is the central pixel, whereas 8 is one of the corner pixels in the 3x3 central area.

# %%
import supertomo.ui.supertomo_options as options
from supertomo.processing.registration import registration
from supertomo.processing import itk

fixed_image = itk.convert_to_itk_image(data[0, 12])
moving_image = itk.convert_to_itk_image(data[0, 8])


args = ("{} --sampling-percentage=1 --reg-relax-factor=.6 --learning-rate=1 --min-step=0.0005 "         
        "--reg-max-iterations=300 --reg-method=correlation --reg-translate-only " 
        "--reg-enable-observers".format(full_path)).split()

options = options.get_ism_script_options(args)

transform = registration.itk_registration_rigid_2d(fixed_image, moving_image, options)
# Out:
# Setting up registration job
# Starting registration
# Final metric value: -0.793967050849
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Step too small after 22 iterations. Current step (0.000470185) is less than minimum step (0.0005).

# %%
print transform
# Out:
# itk::simple::Transform
#  TranslationTransform (0x7f8f9aea64c0)
#    RTTI typeinfo:   itk::TranslationTransform<double, 2u>
#    Reference Count: 2
#    Modified Time: 59816048
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    Offset: [-0.126228, 0.0562331]

# %% [markdown]
# Seems to work fine, so lets do the same for all the images in the dataset. There's a specific ISM alignment function *find_image_shifts(ArrayDataContainer, options)* in SuperTomo that can be used for this puropose. The command line parameters (args) here are tuned more for accuracy rather than speed.

# %%
import supertomo.ui.supertomo_options as options
import supertomo.processing.ism.reconstruction as ismrec

args = ("{} --sampling-percentage=.1 --reg-relax-factor=.6 --learning-rate=1 --min-step=0.0005 "         
        "--reg-max-iterations=300 --reg-method=correlation --reg-translate-only ".format(full_path)).split()

options = options.get_ism_script_options(args)

x,y,tranforms = ismrec.find_image_shifts(data, options)
# Out:
# Setting up registration job
# Starting registration
# Final metric value: -0.44350612185
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 19 iterations. Gradient magnitude (1.30945e-05) is less than gradient magnitude tolerance (0.0001).
# Setting up registration job
# Starting registration
# Final metric value: -0.573275532194
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 18 iterations. Gradient magnitude (3.29009e-05) is less than gradient magnitude tolerance (0.0001).
# Setting up registration job
# Starting registration
# Final metric value: -0.623887744888
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (2.51719e-05) is less than gradient magnitude tolerance (0.0001).
# Setting up registration job
# Starting registration
# Final metric value: -0.584813348371
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 22 iterations. Gradient magnitude (3.7898e-05) is less than gradient magnitude tolerance (0.0001).
# Setting up registration job
# Starting registration
# Final metric value: -0.423129911149
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (8.53657e-05) is less than gradient magnitude tolerance (0.0001).
# Setting up registration job
# Starting registration
# Final metric value: -0.61051375498
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (4.98505e-05) is less than gradient magnitude tolerance (0.0001).
# Setting up registration job
# Starting registration
# Final metric value: -0.801249561572
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (7.47641e-05) is less than gradient magnitude tolerance (0.0001).
# Setting up registration job
# Starting registration
# Final metric value: -0.842470155958
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 17 iterations. Gradient magnitude (1.47728e-05) is less than gradient magnitude tolerance (0.0001).
# Setting up registration job
# Starting registration
# Final metric value: -0.799076604374
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Step too small after 23 iterations. Current step (0.000470185) is less than minimum step (0.0005).
# Setting up registration job
# Starting registration
# Final metric value: -0.572745272485
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 17 iterations. Gradient magnitude (5.9799e-05) is less than gradient magnitude tolerance (0.0001).
# Setting up registration job
# Starting registration
# Final metric value: -0.695554073833
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Step too small after 23 iterations. Current step (0.000470185) is less than minimum step (0.0005).
# Setting up registration job
# Starting registration
# Final metric value: -0.865335645049
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Step too small after 23 iterations. Current step (0.000470185) is less than minimum step (0.0005).
# Setting up registration job
# Starting registration
# Final metric value: -1.0
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 0 iterations. Gradient magnitude (0) is less than gradient magnitude tolerance (0.0001).
# Setting up registration job
# Starting registration
# Final metric value: -0.850313326122
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 22 iterations. Gradient magnitude (3.95426e-05) is less than gradient magnitude tolerance (0.0001).
# Setting up registration job
# Starting registration
# Final metric value: -0.650832057738
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 20 iterations. Gradient magnitude (9.09122e-05) is less than gradient magnitude tolerance (0.0001).
# Setting up registration job
# Starting registration
# Final metric value: -0.655751602244
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Step too small after 27 iterations. Current step (0.000470185) is less than minimum step (0.0005).
# Setting up registration job
# Starting registration
# Final metric value: -0.828654979712
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Step too small after 25 iterations. Current step (0.000470185) is less than minimum step (0.0005).
# Setting up registration job
# Starting registration
# Final metric value: -0.857220927374
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Step too small after 25 iterations. Current step (0.000470185) is less than minimum step (0.0005).
# Setting up registration job
# Starting registration
# Final metric value: -0.799421132789
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (7.37972e-05) is less than gradient magnitude tolerance (0.0001).
# Setting up registration job
# Starting registration
# Final metric value: -0.57830823443
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 22 iterations. Gradient magnitude (6.26739e-05) is less than gradient magnitude tolerance (0.0001).
# Setting up registration job
# Starting registration
# Final metric value: -0.485767615396
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (6.63463e-05) is less than gradient magnitude tolerance (0.0001).
# Setting up registration job
# Starting registration
# Final metric value: -0.644239152672
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 20 iterations. Gradient magnitude (4.6333e-05) is less than gradient magnitude tolerance (0.0001).
# Setting up registration job
# Starting registration
# Final metric value: -0.681702647076
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Step too small after 24 iterations. Current step (0.000470185) is less than minimum step (0.0005).
# Setting up registration job
# Starting registration
# Final metric value: -0.601332692418
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (7.49713e-05) is less than gradient magnitude tolerance (0.0001).
# Setting up registration job
# Starting registration
# Final metric value: -0.469639833183
# Optimizer's stopping condition, RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 17 iterations. Gradient magnitude (3.93882e-05) is less than gradient magnitude tolerance (0.0001).

# %% [markdown]
# # Reassign (fuse)
#
# The simplest reassignment is just a sum of the shifted images. There' a *shift_and_sum()* function in the library for doing this. *image1* is the central detector image and *image2* the reassignment result.

# %%
result = ismrec.shift_and_sum(data, tranforms)

implots.display_2d_images(data[0,12], result.astype(np.uint32))

# %% [markdown]
# ## Realtime reassignment
#
# It would of course be nice to be able to see the reassignment result in realtime during imaging. In order to do that the reassignment has to be run pixel-by-pixel and there's no possibility/time to perform the image alignment. Therefore one has to obtain the shifts beforehad. In theory they could be estimated from the detector specifications (pixel spacing), but in practice, many factors affect the actual shift between the images. Therefore one needs to find the shifts by calibration measurements. Let's see what that looks like.

# %%
import pandas

shifts = pandas.DataFrame({'x': x, 'y': y})

shifts.plot(x='x', y='y', kind='scatter')

# %% [markdown]
# Let's first discretize the shifts by converting from physical units to pixel space. That way one can find out how many pixels each pixel from a given image needs to be shifted in the result image.

# %%
spacing = data[0,0].spacing

shifts['x_px'] = shifts['x']/spacing[0]
shifts['y_px'] = shifts['y']/spacing[1]

shifts.x_px = shifts.x_px.round()
shifts.y_px = shifts.y_px.round()

print shifts
# Out:
#            x         y  x_px  y_px
# 0  -0.123834 -0.281519  -4.0 -10.0
# 1  -0.161103 -0.167512  -6.0  -6.0
# 2  -0.200270 -0.076026  -7.0  -3.0
# 3  -0.249565  0.016176  -9.0   1.0
# 4  -0.295132  0.116909 -10.0   4.0
# 5  -0.001796 -0.211767  -0.0  -7.0
# 6  -0.039994 -0.111332  -1.0  -4.0
# 7  -0.082782 -0.028055  -3.0  -1.0
# 8  -0.127596  0.056267  -4.0   2.0
# 9  -0.173872  0.153152  -6.0   5.0
# 10  0.093833 -0.168534   3.0  -6.0
# 11  0.041496 -0.081489   1.0  -3.0
# 12  0.000000  0.000000   0.0   0.0
# 13 -0.041975  0.085954  -1.0   3.0
# 14 -0.084561  0.187694  -3.0   7.0
# 15  0.191696 -0.153792   7.0  -5.0
# 16  0.131233 -0.057130   5.0  -2.0
# 17  0.079913  0.025660   3.0   1.0
# 18  0.037766  0.118845   1.0   4.0
# 19  0.002314  0.262173   0.0   9.0
# 20  0.336789 -0.143084  12.0  -5.0
# 21  0.235729 -0.032249   8.0  -1.0
# 22  0.176289  0.057516   6.0   2.0
# 23  0.123085  0.160171   4.0   6.0
# 24  0.108359  0.338017   4.0  12.0

# %% [markdown]
# After the calibration has been done, the reassignment is nothing else than a shift and sum operation that is done in the same way for every scan position (j,i).

# %%
from sklearn.externals.joblib import Memory
memory = Memory(cachedir='/tmp', verbose=0)

@memory.cache
def stupid_px_by_px_reassign(data, shifts):
    dims = data[0,0].shape
    spacing = data[0,0].spacing

    result_rt = Image(np.zeros(dims, dtype=np.uint32), spacing)
    
    for j in range(dims[1]):
        for i in range(dims[0]):

            for idx in (7, 11, 12, 13, 17): 
                image = data[0, idx]

                y_shift = int(j - shifts.y_px[idx])
                x_shift = int(i - shifts.x_px[idx]) 

                if x_shift >= 0 and x_shift < dims[1] and y_shift >= 0 and y_shift < dims[0]:
                    result_rt[y_shift, x_shift] += image[j, i]

                else:
                    continue
    return result_rt

result_rt = stupid_px_by_px_reassign(data, shifts)

implots.display_2d_images(data[0,12], result_rt)

# %% [markdown]
# Let's compare the 5 pixel reassignment (image2) to the sum image (normal confocal)

# %%
result_sum = Image(np.zeros(dims, dtype=np.float64), spacing)

for image in data:
    result_sum += image
    
implots.display_2d_images(result_sum.astype(np.int32), result_rt)
